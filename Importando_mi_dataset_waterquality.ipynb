# %% [markdown]
# <a href="https://colab.research.google.com/github/Diehgon/Curso-coderhouse-DS/blob/main/Importando_mi_dataset_waterquality.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/Diehgon/Curso-coderhouse-DS/main/waterquality.csv'
df =pd.read_csv(url)
df
# Out:
#             Date  Salinity (ppt)  DissolvedOxygen (mg/L)   pH  \
# 0     1989-05-11             NaN                     NaN  7.5
# 1     1989-05-18             NaN                    12.0  7.5
# 2     1989-05-25             NaN                     NaN  8.0
# 3     1989-06-01             NaN                    12.0  8.0
# 4     1989-07-11             NaN                     NaN  8.5
# ...          ...             ...                     ...  ...
# 2366         NaN             0.0                     NaN  7.0
# 2367         NaN             NaN                     NaN  NaN
# 2368         NaN             0.0                     3.9  6.5
# 2369         NaN             1.0                     NaN  7.0
# 2370         NaN             0.0                     NaN  NaN
#
#       SecchiDepth (m)  WaterDepth (m)  WaterTemp (C)  AirTemp (C)
# 0                 0.3             0.9           17.0   -17.777778
# 1                 0.2             0.6           17.5    20.500000
# ...

# %%
df.isnull()
# Out:
#        Date  Salinity (ppt)  DissolvedOxygen (mg/L)     pH  SecchiDepth (m)  \
# 0     False            True                    True  False            False
# 1     False            True                   False  False            False
# 2     False            True                    True  False            False
# 3     False            True                   False  False            False
# 4     False            True                    True  False            False
# ...     ...             ...                     ...    ...              ...
# 2366   True           False                    True  False            False
# 2367   True            True                    True   True             True
# 2368   True           False                   False  False            False
# 2369   True           False                    True  False            False
# 2370   True           False                    True   True             True
#
#       WaterDepth (m)  WaterTemp (C)  AirTemp (C)
# ...
